# %% [markdown]
# <a href="https://colab.research.google.com/github/Prana1096/Robotics-Arm/blob/main/Play_store_App_Review_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - **Play store App Review Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Abhishek R. Waghm

# %% [markdown]
# ![pathum-danthanarayana-t8TOMKe6xZU-unsplash.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Utilizing the wealth of data available on the Google Play Store and its associated apps, we embarked on a comprehensive exploration aimed at unearthing valuable insights that could fuel the triumph of app development businesses in the dynamic Android market.
#
# Within this endeavor, each app listing served as a treasure trove of information, featuring vital attributes such as category, user rating, size, and more. Moreover, an auxiliary dataset came into play, comprising user-generated reviews of these Android applications.
#
# Our approach hinged on the principles of Exploratory Data Analysis (EDA), an invaluable tool for uncovering hidden gems within datasets. EDA empowered us to wield a potent arsenal of visual techniques, statistical summaries, and graphical representations. These analytical tools not only enabled us to uncover prevailing trends and patterns but also to critically evaluate our underlying assumptions.
#
# Through this intricate and data-driven journey, we endeavored to decode the enigma of what propels app engagement and ultimately leads to success in the Android app landscape. Our mission was to distill actionable insights from the intricate web of data, offering a compass to guide developers towards app prosperity and prominence.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Nightfurry15398/Play-store-App-Review-Analysis-by-Abhishek-

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# 1. What are the predominant app categories that dominate the Play Store?
# 2. What is the prevailing pricing model among apps, with a focus on distinguishing between paid and free offerings?
# 3. How influential is the user rating in determining an app's success and user engagement?
# 4. When considering target demographics, which app categories should developers prioritize?
# 5. Which app category boasts the highest number of installations, indicating user popularity?
# 6. How does the distribution of apps vary across different genres or thematic classifications?
# 7. To what extent does the recency of app updates impact user ratings and satisfaction?
# 8. What is the impact of an app's pricing model, whether it's paid or free, on its overall user rating?
# 9. How do user reviews and app ratings demonstrate correlation and interdependence?
# 10. Let's delve into the subjectivity of app reviews to better understand user sentiments.
# 11. Is there a proportional relationship between the subjectivity and polarity of app reviews?
# 12. What percentage of app reviews exhibit positive, negative, or neutral sentiments?
# 13. How does sentiment polarity differ between paid and free apps, and what implications does this hold for developers?
# 14. What influence does the content rating of apps have on user perception and adoption?
# 15. Is there a discernible impact of the last update date on app ratings and user satisfaction?
# 16. How are app updates distributed throughout the year, revealing trends in developer activity?
# 17. Can we visualize the distribution of updates for both paid and free apps across different months of the year, offering insights into development cycles?

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
#import library
from ast import increment_lineno
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# load your dataset
file_path = "/content/drive/MyDrive/playstore data/Play Store Data.csv"
ps_df = pd.read_csv(file_path)

# %%
#load your second dataset
file_path2 = "/content/drive/MyDrive/playstore data/User Reviews.csv"
ps_df2 = pd.read_csv(file_path2)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
ps_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
#last five row of data
ps_df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10836       Everyone          Education     July 25, 2017                1.48
# 10837       Everyone          Education      July 6, 2018                 1.0
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device

# %%
#unique values of installations
ps_df["Installs"].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0', 'Free'], dtype=object)

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
ps_df.shape
# Out:
# (10841, 13)

# %%
# Dataset Rows & Columns count
print(ps_df.columns)
rows = ps_df.shape[0]
columns = ps_df.shape[1]
print(f'the following data contains {rows} rows and {columns} columns')
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')
# the following data contains 10841 rows and 13 columns

# %% [markdown]
# In first dataset we have a 10841 rows with 13 columns

# %%
#fisrt five rows of second dataset
ps_df2.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
#last five rows of second dataset
ps_df2.tail()
# Out:
#                                App Translated_Review Sentiment  \
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN

# %%
#shape of second dataset
ps_df2.shape
# Out:
# (64295, 5)

# %% [markdown]
# In the second dataset, we have 64295 rows and 5 columns their is lots of null values in it

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
ps_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
#rating statistics
ps_df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# In this, we show that there are 9367 rows with values there is some row with above 5 rating

# %%
ps_df2.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

# %%
#duplicate values of first data set
len(ps_df[ps_df.duplicated()])
# Out:
# 483

# %%
#duplicate values of second data set
len(ps_df2[ps_df2.duplicated()])
# Out:
# 33616

# %%
#There is one row contain some error so we drop that row
ps_df[ps_df["Rating"]>5]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
play_store_df=ps_df.drop(ps_df.index[[10472]])

# %%
play_store_df.shape
# Out:
# (10840, 13)

# %%
play_store_df.describe()
# Out:
#             Rating
# count  9366.000000
# mean      4.191757
# std       0.515219
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max       5.000000

# %%
#list of columns
print(list(play_store_df.columns))
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']

# %%
#info of dataset
play_store_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  object
#  4   Size            10840 non-null  object
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.2+ MB

# %% [markdown]
# #### Missing Values/Null Values

# %%
null_values= ps_df.isnull().sum()
null_values
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(ps_df.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
# null vaues of second data set
null_values= ps_df2.isnull().sum()
null_values
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
#heatmap for null values of second daset
# Visualizing the missing values
sns.heatmap(ps_df2.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# -There are 13 columns of properties with 10841 rows of data.
#
# -Column 'Reviews', 'Size', 'Installs' and 'Price' are in the type of 'object'
#
# -Values of column 'Size' are strings representing size in 'M' as Megabytes, 'k' as kilobytes and also 'Varies with devices'.
#
# -Values of column 'Installs' are strings representing install amount with symbols such as ',' and '+'.
#
# -Values of column 'Price' are strings representing price with symbol '$'.

# %% [markdown]
# ## **data cleaning and framing**

# %%
# convert reviews type as integer type
play_store_df = play_store_df.astype({"Reviews": int})

# %%
#drop $ sign from price column
play_store_df['Price'] = play_store_df['Price'].str.replace('$','')
# Out:
# <ipython-input-33-901ca25083e9>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   play_store_df['Price'] = play_store_df['Price'].str.replace('$','')

# %%
#convert price column type as float
play_store_df = play_store_df.astype({"Price": float})

# %%
#in installs column we replace some sign and convert it into integer data type
play_store_df['Installs'] = play_store_df['Installs'].str.replace(',','')
play_store_df['Installs'] = play_store_df['Installs'].str.replace('+','')
play_store_df = play_store_df.astype({"Installs": int})
# Out:
# <ipython-input-35-10c5b83c0106>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   play_store_df['Installs'] = play_store_df['Installs'].str.replace('+','')

# %%
#In size column apps size in mb and kb
play_store_df["Size"].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
#        '5.1M', '61M', '66M', '79k', '8.4M', '118k', '44M', '695k', '1.6M',
#        '6.2M', '18k', '53M', '1.4M', '3.0M', '5.8M', '3.8M', '9.6M',
#        '45M', '63M', '49M', '77M', '4.4M', '4.8M', '70M', '6.9M', '9.3M',
#        '10.0M', '8.1M', '36M', '84M', '97M', '2.0M', '1.9M', '1.8M',
#        '5.3M', '47M', '556k', '526k', '76M', '7.6M', '59M', '9.7M', '78M',
#        '72M', '43M', '7.7M', '6.3M', '334k', '34M', '93M', '65M', '79M',
#        '100M', '58M', '50M', '68M', '64M', '67M', '60M', '94M', '232k',
#        '99M', '624k', '95M', '8.5k', '41k', '292k', '11k', '80M', '1.7M',
#        '74M', '62M', '69M', '75M', '98M', '85M', '82M', '96M', '87M',
#        '71M', '86M', '91M', '81M', '92M', '83M', '88M', '704k', '862k',
#        '899k', '378k', '266k', '375k', '1.3M', '975k', '980k', '4.1M',
#        '89M', '696k', '544k', '525k', '920k', '779k', '853k', '720k',
#        '713k', '772k', '318k', '58k', '241k', '196k', '857k', '51k',
#        '953k', '865k', '251k', '930k', '540k', '313k', '746k', '203k',
#        '26k', '314k', '239k', '371k', '220k', '730k', '756k', '91k',
#        '293k', '17k', '74k', '14k', '317k', '78k', '924k', '902k', '818k',
#        '81k', '939k', '169k', '45k', '475k', '965k', '90M', '545k', '61k',
#        '283k', '655k', '714k', '93k', '872k', '121k', '322k', '1.0M',
#        '976k', '172k', '238k', '549k', '206k', '954k', '444k', '717k',
#        '210k', '609k', '308k', '705k', '306k', '904k', '473k', '175k',
#        '350k', '383k', '454k', '421k', '70k', '812k', '442k', '842k',
#        '417k', '412k', '459k', '478k', '335k', '782k', '721k', '430k',
#        '429k', '192k', '200k', '460k', '728k', '496k', '816k', '414k',
#        '506k', '887k', '613k', '243k', '569k', '778k', '683k', '592k',
#        '319k', '186k', '840k', '647k', '191k', '373k', '437k', '598k',
#        '716k', '585k', '982k', '222k', '219k', '55k', '948k', '323k',
#        '691k', '511k', '951k', '963k', '25k', '554k', '351k', '27k',
#        '82k', '208k', '913k', '514k', '551k', '29k', '103k', '898k',
#        '743k', '116k', '153k', '209k', '353k', '499k', '173k', '597k',
#        '809k', '122k', '411k', '400k', '801k', '787k', '237k', '50k',
#        '643k', '986k', '97k', '516k', '837k', '780k', '961k', '269k',
#        '20k', '498k', '600k', '749k', '642k', '881k', '72k', '656k',
#        '601k', '221k', '228k', '108k', '940k', '176k', '33k', '663k',
#        '34k', '942k', '259k', '164k', '458k', '245k', '629k', '28k',
#        '288k', '775k', '785k', '636k', '916k', '994k', '309k', '485k',
#        '914k', '903k', '608k', '500k', '54k', '562k', '847k', '957k',
#        '688k', '811k', '270k', '48k', '329k', '523k', '921k', '874k',
#        '981k', '784k', '280k', '24k', '518k', '754k', '892k', '154k',
#        '860k', '364k', '387k', '626k', '161k', '879k', '39k', '970k',
#        '170k', '141k', '160k', '144k', '143k', '190k', '376k', '193k',
#        '246k', '73k', '658k', '992k', '253k', '420k', '404k', '470k',
#        '226k', '240k', '89k', '234k', '257k', '861k', '467k', '157k',
#        '44k', '676k', '67k', '552k', '885k', '1020k', '582k', '619k'],
#       dtype=object)

# %% [markdown]
# Since, size of the applications present in the datset are in MB and KB. Therefore, for ease in data processing, entire size column is converted to MB.

# %%
#After converted
play_store_df["Size"].unique()
# Out:
# array([1.90e+01, 1.40e+01, 8.70e+00, 2.50e+01, 2.80e+00, 5.60e+00,
#        2.90e+01, 3.30e+01, 3.10e+00, 2.80e+01, 1.20e+01, 2.00e+01,
#        2.10e+01, 3.70e+01, 2.70e+00, 5.50e+00, 1.70e+01, 3.90e+01,
#        3.10e+01, 4.20e+00, 7.00e+00, 2.30e+01, 6.00e+00, 6.10e+00,
#        4.60e+00, 9.20e+00, 5.20e+00, 1.10e+01, 2.40e+01, 9.40e+00,
#        1.50e+01, 1.00e+01, 1.20e+00, 2.60e+01, 8.00e+00, 7.90e+00,
#        5.60e+01, 5.70e+01, 3.50e+01, 5.40e+01, 2.01e-01, 3.60e+00,
#        5.70e+00, 8.60e+00, 2.40e+00, 2.70e+01, 2.50e+00, 1.60e+01,
#        3.40e+00, 8.90e+00, 3.90e+00, 2.90e+00, 3.80e+01, 3.20e+01,
#        5.40e+00, 1.80e+01, 1.10e+00, 2.20e+00, 4.50e+00, 9.80e+00,
#        5.20e+01, 9.00e+00, 6.70e+00, 3.00e+01, 2.60e+00, 7.10e+00,
#        3.70e+00, 2.20e+01, 7.40e+00, 6.40e+00, 3.20e+00, 8.20e+00,
#        9.90e+00, 4.90e+00, 9.50e+00, 5.00e+00, 5.90e+00, 1.30e+01,
#        7.30e+01, 6.80e+00, 3.50e+00, 4.00e+00, 2.30e+00, 7.20e+00,
#        2.10e+00, 4.20e+01, 7.30e+00, 9.10e+00, 5.50e+01, 2.30e-02,
#        6.50e+00, 1.50e+00, 7.50e+00, 5.10e+01, 4.10e+01, 4.80e+01,
#        8.50e+00, 4.60e+01, 8.30e+00, 4.30e+00, 4.70e+00, 3.30e+00,
#        4.00e+01, 7.80e+00, 8.80e+00, 6.60e+00, 5.10e+00, 6.10e+01,
#        6.60e+01, 7.90e-02, 8.40e+00, 1.18e-01, 4.40e+01, 6.95e-01,
#        1.60e+00, 6.20e+00, 1.80e-02, 5.30e+01, 1.40e+00, 3.00e+00,
#        5.80e+00, 3.80e+00, 9.60e+00, 4.50e+01, 6.30e+01, 4.90e+01,
#        7.70e+01, 4.40e+00, 4.80e+00, 7.00e+01, 6.90e+00, 9.30e+00,
#        8.10e+00, 3.60e+01, 8.40e+01, 9.70e+01, 2.00e+00, 1.90e+00,
#        1.80e+00, 5.30e+00, 4.70e+01, 5.56e-01, 5.26e-01, 7.60e+01,
#        7.60e+00, 5.90e+01, 9.70e+00, 7.80e+01, 7.20e+01, 4.30e+01,
#        7.70e+00, 6.30e+00, 3.34e-01, 3.40e+01, 9.30e+01, 6.50e+01,
#        7.90e+01, 1.00e+02, 5.80e+01, 5.00e+01, 6.80e+01, 6.40e+01,
#        6.70e+01, 6.00e+01, 9.40e+01, 2.32e-01, 9.90e+01, 6.24e-01,
#        9.50e+01, 8.50e-03, 4.10e-02, 2.92e-01, 1.10e-02, 8.00e+01,
#        1.70e+00, 7.40e+01, 6.20e+01, 6.90e+01, 7.50e+01, 9.80e+01,
#        8.50e+01, 8.20e+01, 9.60e+01, 8.70e+01, 7.10e+01, 8.60e+01,
#        9.10e+01, 8.10e+01, 9.20e+01, 8.30e+01, 8.80e+01, 7.04e-01,
#        8.62e-01, 8.99e-01, 3.78e-01, 2.66e-01, 3.75e-01, 1.30e+00,
#        9.75e-01, 9.80e-01, 4.10e+00, 8.90e+01, 6.96e-01, 5.44e-01,
#        5.25e-01, 9.20e-01, 7.79e-01, 8.53e-01, 7.20e-01, 7.13e-01,
#        7.72e-01, 3.18e-01, 5.80e-02, 2.41e-01, 1.96e-01, 8.57e-01,
#        5.10e-02, 9.53e-01, 8.65e-01, 2.51e-01, 9.30e-01, 5.40e-01,
#        3.13e-01, 7.46e-01, 2.03e-01, 2.60e-02, 3.14e-01, 2.39e-01,
#        3.71e-01, 2.20e-01, 7.30e-01, 7.56e-01, 9.10e-02, 2.93e-01,
#        1.70e-02, 7.40e-02, 1.40e-02, 3.17e-01, 7.80e-02, 9.24e-01,
#        9.02e-01, 8.18e-01, 8.10e-02, 9.39e-01, 1.69e-01, 4.50e-02,
#        4.75e-01, 9.65e-01, 9.00e+01, 5.45e-01, 6.10e-02, 2.83e-01,
#        6.55e-01, 7.14e-01, 9.30e-02, 8.72e-01, 1.21e-01, 3.22e-01,
#        1.00e+00, 9.76e-01, 1.72e-01, 2.38e-01, 5.49e-01, 2.06e-01,
#        9.54e-01, 4.44e-01, 7.17e-01, 2.10e-01, 6.09e-01, 3.08e-01,
#        7.05e-01, 3.06e-01, 9.04e-01, 4.73e-01, 1.75e-01, 3.50e-01,
#        3.83e-01, 4.54e-01, 4.21e-01, 7.00e-02, 8.12e-01, 4.42e-01,
#        8.42e-01, 4.17e-01, 4.12e-01, 4.59e-01, 4.78e-01, 3.35e-01,
#        7.82e-01, 7.21e-01, 4.30e-01, 4.29e-01, 1.92e-01, 2.00e-01,
#        4.60e-01, 7.28e-01, 4.96e-01, 8.16e-01, 4.14e-01, 5.06e-01,
#        8.87e-01, 6.13e-01, 2.43e-01, 5.69e-01, 7.78e-01, 6.83e-01,
#        5.92e-01, 3.19e-01, 1.86e-01, 8.40e-01, 6.47e-01, 1.91e-01,
#        3.73e-01, 4.37e-01, 5.98e-01, 7.16e-01, 5.85e-01, 9.82e-01,
#        2.22e-01, 2.19e-01, 5.50e-02, 9.48e-01, 3.23e-01, 6.91e-01,
#        5.11e-01, 9.51e-01, 9.63e-01, 2.50e-02, 5.54e-01, 3.51e-01,
#        2.70e-02, 8.20e-02, 2.08e-01, 9.13e-01, 5.14e-01, 5.51e-01,
#        2.90e-02, 1.03e-01, 8.98e-01, 7.43e-01, 1.16e-01, 1.53e-01,
#        2.09e-01, 3.53e-01, 4.99e-01, 1.73e-01, 5.97e-01, 8.09e-01,
#        1.22e-01, 4.11e-01, 4.00e-01, 8.01e-01, 7.87e-01, 2.37e-01,
#        5.00e-02, 6.43e-01, 9.86e-01, 9.70e-02, 5.16e-01, 8.37e-01,
#        7.80e-01, 9.61e-01, 2.69e-01, 2.00e-02, 4.98e-01, 6.00e-01,
#        7.49e-01, 6.42e-01, 8.81e-01, 7.20e-02, 6.56e-01, 6.01e-01,
#        2.21e-01, 2.28e-01, 1.08e-01, 9.40e-01, 1.76e-01, 3.30e-02,
#        6.63e-01, 3.40e-02, 9.42e-01, 2.59e-01, 1.64e-01, 4.58e-01,
#        2.45e-01, 6.29e-01, 2.80e-02, 2.88e-01, 7.75e-01, 7.85e-01,
#        6.36e-01, 9.16e-01, 9.94e-01, 3.09e-01, 4.85e-01, 9.14e-01,
#        9.03e-01, 6.08e-01, 5.00e-01, 5.40e-02, 5.62e-01, 8.47e-01,
#        9.57e-01, 6.88e-01, 8.11e-01, 2.70e-01, 4.80e-02, 3.29e-01,
#        5.23e-01, 9.21e-01, 8.74e-01, 9.81e-01, 7.84e-01, 2.80e-01,
#        2.40e-02, 5.18e-01, 7.54e-01, 8.92e-01, 1.54e-01, 8.60e-01,
#        3.64e-01, 3.87e-01, 6.26e-01, 1.61e-01, 8.79e-01, 3.90e-02,
#        9.70e-01, 1.70e-01, 1.41e-01, 1.60e-01, 1.44e-01, 1.43e-01,
#        1.90e-01, 3.76e-01, 1.93e-01, 2.46e-01, 7.30e-02, 6.58e-01,
#        9.92e-01, 2.53e-01, 4.20e-01, 4.04e-01, 4.70e-01, 2.26e-01,
#        2.40e-01, 8.90e-02, 2.34e-01, 2.57e-01, 8.61e-01, 4.67e-01,
#        1.57e-01, 4.40e-02, 6.76e-01, 6.70e-02, 5.52e-01, 8.85e-01,
#        1.02e+00, 5.82e-01, 6.19e-01])

# %%
#data info after cleaning
play_store_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            10840 non-null  float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.2+ MB

# %% [markdown]
# After changing the data type, now we have some columns in float and int types.

# %%
play_store_df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews  Size  Installs  Type  Price Content Rating  \
# 10836     4.5       38  53.0      5000  Free    0.0       Everyone
# 10837     5.0        4   3.6       100  Free    0.0       Everyone
# 10838     NaN        3   9.5      1000  Free    0.0       Everyone
# 10839     4.5      114  20.0      1000  Free    0.0     Mature 17+
# 10840     4.5   398307  19.0  10000000  Free    0.0       Everyone
#
#                   Genres      Last Updated         Current Ver  \
# 10836          Education     July 25, 2017                1.48
# 10837          Education      July 6, 2018                 1.0
# 10838            Medical  January 20, 2017                 1.0
# 10839  Books & Reference  January 19, 2015  Varies with device
# 10840          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device

# %%
#unique apps
df_df=play_store_df["App"].nunique()
df_df
# Out:
# 9659

# %%
#drop the duplicate apps
right_df=play_store_df.drop_duplicates(subset='App')
right_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
#null values in rating-1463
right_df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1463
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %% [markdown]
# **Here, we realized that there are 1463 rows having null values under column 'Rating'. Hence, we decided to replace the null values with mean of overall 'Rating' values.**

# %%
#replace the null value
right_df.Rating.fillna(4.19, inplace=True)
# Out:
# <ipython-input-40-5b8f148f8a01>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   right_df.Rating.fillna(4.19, inplace=True)

# %%
#After cleaning
right_df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       2
# dtype: int64

# %% [markdown]
# **Afer the cleaning process now we have a right data set**

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
#some values count
right_df.describe()
# Out:
#             Rating       Reviews         Size      Installs        Price
# count  9659.000000  9.659000e+03  9659.000000  9.659000e+03  9659.000000
# mean      4.175781  2.165926e+05    20.345075  7.777507e+06     1.099299
# std       0.494349  1.831320e+06    20.394348  5.375828e+07    16.852152
# min       1.000000  0.000000e+00     0.008500  0.000000e+00     0.000000
# 25%       4.000000  2.500000e+01     5.300000  1.000000e+03     0.000000
# 50%       4.200000  9.670000e+02    16.000000  1.000000e+05     0.000000
# 75%       4.500000  2.940100e+04    25.000000  1.000000e+06     0.000000
# max       5.000000  7.815831e+07   100.000000  1.000000e+09   400.000000

# %%
#list of category
number_of_category=right_df["Category"].unique()
print(number_of_category)
# Out:
# ['ART_AND_DESIGN' 'AUTO_AND_VEHICLES' 'BEAUTY' 'BOOKS_AND_REFERENCE'
#  'BUSINESS' 'COMICS' 'COMMUNICATION' 'DATING' 'EDUCATION' 'ENTERTAINMENT'
#  'EVENTS' 'FINANCE' 'FOOD_AND_DRINK' 'HEALTH_AND_FITNESS' 'HOUSE_AND_HOME'
#  'LIBRARIES_AND_DEMO' 'LIFESTYLE' 'GAME' 'FAMILY' 'MEDICAL' 'SOCIAL'
#  'SHOPPING' 'PHOTOGRAPHY' 'SPORTS' 'TRAVEL_AND_LOCAL' 'TOOLS'
#  'PERSONALIZATION' 'PRODUCTIVITY' 'PARENTING' 'WEATHER' 'VIDEO_PLAYERS'
#  'NEWS_AND_MAGAZINES' 'MAPS_AND_NAVIGATION']

# %%
right_df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews  Size  Installs  Type  Price Content Rating  \
# 10836    4.50       38  53.0      5000  Free    0.0       Everyone
# 10837    5.00        4   3.6       100  Free    0.0       Everyone
# 10838    4.19        3   9.5      1000  Free    0.0       Everyone
# 10839    4.50      114  20.0      1000  Free    0.0     Mature 17+
# 10840    4.50   398307  19.0  10000000  Free    0.0       Everyone
#
#                   Genres      Last Updated         Current Ver  \
# 10836          Education     July 25, 2017                1.48
# 10837          Education      July 6, 2018                 1.0
# 10838            Medical  January 20, 2017                 1.0
# 10839  Books & Reference  January 19, 2015  Varies with device
# 10840          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device

# %%
# Dataset Columns

# %%
# Dataset Describe

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **Dataset-1**
#
# App: It contains the name of the app with a short description (optional).
#
# Category: This section gives the category to which an app belongs. In this
#
# dataset, the apps are divided among 33 categories.
#
# Size: The disk space required to install the respective app.
#
# Rating: The average rating given by the users for the respective app. It can be in between 1 and 5.
#
# Reviews: The number of users that have dropped a review for the respective app.
#
# Installs: The approximate number of times the respective app was installed.
#
# Type: It states whether an app is free to use or paid.
#
# Price: It gives the price payable to install the app. For free type apps, the price is zero.
#
# Content rating: It states which age group is suitable to consume the content of the respective app.
#
# Genres: It gives the genre(s) to which the respective app belongs.
#
# Last updated: It gives the day in which the latest update for the respective app was released.
#
# Current Ver: It gives the current version of the respective app.
#
# Android Ver: It gives the android version of the respective app.
#
# **Dataset-2**
#
# App: It contains the name of the app with a short description (optional).
#
# Translated_Review: It contains the English translation of the review dropped by the user of the app.
#
# Sentiment: It gives the attitude/emotion of the writer. It can be ‘Positive’, ‘Negative’, or ‘Neutral’.
#
# Sentiment_Polarity: It gives the polarity of the review. Its range is [-1,1], where 1 means ‘Positive statement’ and -1 means a ‘Negative statement’.
#
# Sentiment_Subjectivity: This value gives how close a reviewer’s opinion is to the opinion of the general public. Its range is [0,1]. Higher the subjectivity, closer is the reviewer’s opinion to the opinion of the general public, and lower subjectivity indicates the review is more of a factual information

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

# %%
right_df["App"].nunique()
# Out:
# 9659

# %%
right_df["Category"].nunique()
# Out:
# 33

# %%
right_df["Type"].nunique()
# Out:
# 2

# %%
right_df["Price"].nunique()
# Out:
# 92

# %%
right_df["Price"].max()
# Out:
# 400.0

# %%
right_df["Genres"].nunique()
# Out:
# 118

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
#data based on rating vs price
price_df=right_df[["App","Price","Type","Rating","Size"]]
price_df.head()
# Out:
#                                                  App  Price  Type  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook    0.0  Free     4.1
# 1                                Coloring book moana    0.0  Free     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...    0.0  Free     4.7
# 3                              Sketch - Draw & Paint    0.0  Free     4.5
# 4              Pixel Draw - Number Art Coloring Book    0.0  Free     4.3
#
#    Size
# 0  19.0
# 1  14.0
# 2   8.7
# 3  25.0
# 4   2.8

# %%
#apps content rating
grouped = right_df[['App','Content Rating']]
grouped
# Out:
#                                                      App Content Rating
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       Everyone
# 1                                    Coloring book moana       Everyone
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       Everyone
# 3                                  Sketch - Draw & Paint           Teen
# 4                  Pixel Draw - Number Art Coloring Book       Everyone
# ...                                                  ...            ...
# 10836                                   Sya9a Maroc - FR       Everyone
# 10837                   Fr. Mike Schmitz Audio Teachings       Everyone
# 10838                             Parkinson Exercices FR       Everyone
# 10839                      The SCP Foundation DB fr nn5n     Mature 17+
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology       Everyone
#
# [9659 rows x 2 columns]

# %%
#apps age group
age_grouped= grouped.rename(columns={'Content Rating': 'age_group'})
age_grouped
# Out:
#                                                      App   age_group
# 0         Photo Editor & Candy Camera & Grid & ScrapBook    Everyone
# 1                                    Coloring book moana    Everyone
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...    Everyone
# 3                                  Sketch - Draw & Paint        Teen
# 4                  Pixel Draw - Number Art Coloring Book    Everyone
# ...                                                  ...         ...
# 10836                                   Sya9a Maroc - FR    Everyone
# 10837                   Fr. Mike Schmitz Audio Teachings    Everyone
# 10838                             Parkinson Exercices FR    Everyone
# 10839                      The SCP Foundation DB fr nn5n  Mature 17+
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology    Everyone
#
# [9659 rows x 2 columns]

# %%
#android version of apps
versions=right_df["Android Ver"].value_counts().reset_index()
versions = versions.rename(columns={'index':'Android Ver','Android Ver': 'count'})
versions
# Out:
#            Android Ver  count
# 0           4.1 and up   2202
# 1         4.0.3 and up   1395
# 2           4.0 and up   1285
# 3   Varies with device    990
# 4           4.4 and up    818
# 5           2.3 and up    616
# 6           5.0 and up    512
# 7           4.2 and up    372
# 8         2.3.3 and up    273
# 9           2.2 and up    239
# 10          3.0 and up    231
# 11          4.3 and up    221
# 12          2.1 and up    133
# 13          1.6 and up    116
# 14          6.0 and up     54
# 15          7.0 and up     42
# 16          3.2 and up     36
# 17          2.0 and up     32
# 18          5.1 and up     22
# 19          1.5 and up     20
# 20         4.4W and up     11
# 21          3.1 and up     10
# 22        2.0.1 and up      7
# 23          8.0 and up      6
# 24          7.1 and up      3
# 25       4.0.3 - 7.1.1      2
# 26           5.0 - 8.0      2
# 27          1.0 and up      2
# 28         7.0 - 7.1.1      1
# 29         4.1 - 7.1.1      1
# 30           5.0 - 6.0      1
# 31         2.2 - 7.1.1      1
# 32         5.0 - 7.1.1      1

# %%
#total apps based on category
df=right_df.groupby('Category')['App'].nunique().reset_index(name="Total Apps")
df=df.sort_values(by=['Total Apps'],ascending=False)
df
# Out:
#                Category  Total Apps
# 11               FAMILY        1832
# 14                 GAME         959
# 29                TOOLS         827
# 4              BUSINESS         420
# 20              MEDICAL         395
# 23      PERSONALIZATION         376
# 25         PRODUCTIVITY         374
# 18            LIFESTYLE         369
# 12              FINANCE         345
# 28               SPORTS         325
# 6         COMMUNICATION         315
# 15   HEALTH_AND_FITNESS         288
# 24          PHOTOGRAPHY         281
# 21   NEWS_AND_MAGAZINES         254
# 27               SOCIAL         239
# 3   BOOKS_AND_REFERENCE         222
# 30     TRAVEL_AND_LOCAL         219
# 26             SHOPPING         202
# 7                DATING         171
# 31        VIDEO_PLAYERS         163
# 19  MAPS_AND_NAVIGATION         131
# 8             EDUCATION         119
# 13       FOOD_AND_DRINK         112
# 9         ENTERTAINMENT         102
# 1     AUTO_AND_VEHICLES          85
# 17   LIBRARIES_AND_DEMO          84
# 32              WEATHER          79
# 16       HOUSE_AND_HOME          74
# 10               EVENTS          64
# 0        ART_AND_DESIGN          64
# 22            PARENTING          60
# 5                COMICS          56
# 2                BEAUTY          53

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - bar graph on distrubution over catdegory

# %% [markdown]
# ## Chart - 1 pie chart

# %%
# Chart - 1 visualization code
#pie chart on price of apps
plt.figure(figsize=(8,6))
plt.title("Apps on price",fontsize = 16)
plt.pie(price_df.Type.value_counts(), labels=price_df.Type.value_counts().index,autopct='%1.1f%%',startangle=90,explode=(0, 0.1))
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts show the parts-to-whole relationship
#
# Pie charts are often used in business. Examples include showing percentages of types of customers, percentage of revenue from different products, and profits from different countries.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the plot we can imply that majority of the apps in the Play Store are Free apps.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From the above pie chart, we can draw insight that most of the apps are free (approx 92%) and paid apps (approx 7%) Listing. It may lead to fewer installations of paid apps.

# %% [markdown]
# #### Chart - 2 pie chart

# %%
# Chart - 2 visualization code
#age group on apps
plt.figure(figsize=(10,6))
plt.title("Apps per age group",fontsize = 16)
plt.pie(age_grouped.age_group.value_counts(), labels=age_grouped.age_group.value_counts().index,autopct='%1.1f%%',startangle=180,explode=(0.1, 0,0,0,1,2.5))
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
# Pie charts show the parts-to-whole relationship
#
# So here we display the percentage of Apps with different age group restrictions

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# From the above plot, we can see that the Everyone category has the highest number of apps.

# %% [markdown]
# **3 . Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# From the above piechart we can show that most of the apps are no age restriction mins they will gain more users, restricted apps are fewer users base

# %% [markdown]
# #### Chart - 3 bar plaot

# %%
# Chart - 3 visualization code
#total apps based on versions
plt.figure(figsize=(20,6))
plt.title("Apps Android versions",fontsize=16)
sns.barplot(data=versions,x="Android Ver",y="count")
plt.xticks(rotation= 90)
plt.xlabel('Categorys',fontsize=16)
plt.ylabel('Total Apps',fontsize=16)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar chart should be used when we are showing segment of information.
# So, here i want to show the segment of app version that's why i chose a bar graph.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the app based on the android version 4.1 and above

# %% [markdown]
#  3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# most of the apps are based on the android version 4.1 but some of the apps are are not compatible with the current versions.

# %% [markdown]
# #### Chart - 4 bar plot

# %%
# Chart - 4 visualization code
plt.figure(figsize=(20,6))
plt.title("Total Apps on category",fontsize=16)
sns.barplot(data=df,x="Category",y="Total Apps")
plt.xticks(rotation= 90)
plt.xlabel('Categorys',fontsize=16)
plt.ylabel('Total Apps',fontsize=16)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# bar chart should be used when we are showing segment of information.
# so, here in want to show the segment of aps  caegory that's why i choose a bar graph.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this plotting we know that most of the apps in playstore are from the categories of 'Family','Games'and also 'Tools'.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From this grafh we can say taht most of the apps are from the category family, game ,tools and beauty , comics category apps are fewer on the play store So it's better to list an app in the category like Beuty, comics, etc.

# %% [markdown]
# #### Chart - 5 Bar Plot

# %%
# Chart - 5 visualization code
#top apps by category
category=df.sort_values(by='Total Apps', ascending=False)
top_five_category=category.head()
least_five_category=category.tail()

# %%
#top category
top_five_category.reset_index()
# Out:
#    index  Category  Total Apps
# 0     11    FAMILY        1832
# 1     14      GAME         959
# 2     29     TOOLS         827
# 3      4  BUSINESS         420
# 4     20   MEDICAL         395

# %%
#bar graph of top five category
fig = plt.figure(figsize = (7, 5))
sns.barplot(data=top_five_category, x="Category", y="Total Apps")
plt.title("Top five Category of listed apps",fontsize=16)
plt.xlabel("Category",fontsize=16)
plt.ylabel("Total Apps",fontsize=16)
plt.show()

# %% [markdown]
# Top five categories on the play store where most of the apps are listed.
#
# 1-Family
#
# 2-Games
#
# 3-Tools
#
# 4-Buissness
#
# 5-Medical

# %% [markdown]
# ## Chart - 6 Bar Plot

# %%
# Chart - 6 visualization code
#least five category
least_five_category.reset_index()
# Out:
#    index        Category  Total Apps
# 0     10          EVENTS          64
# 1      0  ART_AND_DESIGN          64
# 2     22       PARENTING          60
# 3      5          COMICS          56
# 4      2          BEAUTY          53

# %%
#bar graph on least category
fig = plt.figure(figsize = (7, 5))
sns.barplot(data=least_five_category, x="Category", y="Total Apps")
plt.title("Least five Category of listed apps",fontsize=16)
plt.xlabel("Category",fontsize=16)
plt.ylabel("Total Apps",fontsize=16)
plt.show()

# %% [markdown]
# Least five categories were appps are least listed.
#
# 1-Beauty
#
# 2-Comics
#
# 3-Parenting
#
# 4-Art & Desighn
#
# 5-Event

# %% [markdown]
# #### Chart - 7  Bar Plot

# %%
# Chart - 7 visualization code
#number of istalls based on category
categories= right_df.groupby('Category')["Installs"].sum().reset_index()
category_installs_sum_df=categories.sort_values(by='Installs', ascending=False)
category_installs_sum_df
# Out:
#                Category     Installs
# 14                 GAME  13878924415
# 6         COMMUNICATION  11038276251
# 29                TOOLS   8001771915
# 25         PRODUCTIVITY   5793091369
# 27               SOCIAL   5487867902
# 24          PHOTOGRAPHY   4649147655
# 11               FAMILY   4427941505
# 31        VIDEO_PLAYERS   3926902720
# 30     TRAVEL_AND_LOCAL   2894887146
# 21   NEWS_AND_MAGAZINES   2369217760
# 9         ENTERTAINMENT   2113660000
# 3   BOOKS_AND_REFERENCE   1665969576
# 23      PERSONALIZATION   1532494782
# 26             SHOPPING   1400348785
# 15   HEALTH_AND_FITNESS   1144022512
# 28               SPORTS   1096474498
# 4              BUSINESS    697164865
# 18            LIFESTYLE    503823539
# 19  MAPS_AND_NAVIGATION    503281890
# 12              FINANCE    455348734
# 32              WEATHER    361100520
# 8             EDUCATION    352952000
# 13       FOOD_AND_DRINK    211798751
# 7                DATING    140926107
# 0        ART_AND_DESIGN    114338100
# 16       HOUSE_AND_HOME     97212461
# 1     AUTO_AND_VEHICLES     53130211
# 17   LIBRARIES_AND_DEMO     52995910
# 5                COMICS     44981150
# 20              MEDICAL     38193177
# 22            PARENTING     31521110
# 2                BEAUTY     27197050
# 10               EVENTS     15973161

# %%
#bar graph on category vice installetions
plt.figure(figsize=(20, 6))
sns.barplot(x='Category', y='Installs', data=category_installs_sum_df)
plt.xticks(rotation=90)
plt.xlabel("Category",fontsize=16)
plt.ylabel('Installs (e+10)',fontsize=16)
plt.title('Number of Installs For Each Category',fontsize=16)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts used when we are showing segment information.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this distribution plotting of number of installs for each category, we can see that most of the apps being downloaded and installed are from the categories of 'Game' and 'Communication'.
#
# From the above two plots we can conclude that, maximum number of apps present in google play store comes under Family, Games and Tools Category but as per the installations and requirements in the market place, this is not the case. Maximum installed apps comes under Games, Communication and Tools.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From the above visualization, we can say that it is profitable to list a game on the play store but in the category like event and beauty it may lead a negative growth of business and apps.

# %% [markdown]
# #### Chart - 8 Box Plot

# %%
# Chart - 8 visualization code
#data frame df1
df1 =right_df[["App","Category","Rating","Reviews","Installs","Price","Type","Genres","Content Rating","Size"]]
df1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews  Installs  Price  Type                     Genres  \
# 0        4.10      159     10000    0.0  Free               Art & Design
# 1        3.90      967    500000    0.0  Free  Art & Design;Pretend Play
# 2        4.70    87510   5000000    0.0  Free               Art & Design
# 3        4.50   215644  50000000    0.0  Free               Art & Design
# 4        4.30      967    100000    0.0  Free    Art & Design;Creativity
# ...       ...      ...       ...    ...   ...                        ...
# 10836    4.50       38      5000    0.0  Free                  Education
# 10837    5.00        4       100    0.0  Free                  Education
# 10838    4.19        3      1000    0.0  Free                    Medical
# 10839    4.50      114      1000    0.0  Free          Books & Reference
# 10840    4.50   398307  10000000    0.0  Free                  Lifestyle
#
#       Content Rating  Size
# 0           Everyone  19.0
# 1           Everyone  14.0
# 2           Everyone   8.7
# 3               Teen  25.0
# 4           Everyone   2.8
# ...              ...   ...
# 10836       Everyone  53.0
# 10837       Everyone   3.6
# 10838       Everyone   9.5
# 10839     Mature 17+  20.0
# 10840       Everyone  19.0
#
# [9659 rows x 10 columns]

# %%
#box plot on average rating
plt.figure(figsize=(15,8))
plt.title("Average rating on Category",fontsize=16)
sns.boxplot(y="Category",x ='Rating',data =df1)
plt.xlabel("Rating",fontsize=16)
plt.ylabel("Category",fontsize=16)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Box Plot is also known as Whisker plot is created to display the summary of the set of data values having properties like minimum, first quartile, median, third quartile and maximum

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this distribution plotting, it implies that most of the apps in the Play Store are having rating higher than 4 or in the range of 4 to 4.5.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From the box plot, we insight that most of the apps have ratings between 4 - 4.5. The maximum and minimum rating categories are parenting and video players respectively

# %% [markdown]
# #### Chart - 9 Histogram

# %%
# Chart - 9 visualization code
#histogram on size
plt.figure(figsize=(10, 6))
plt.hist(df1['Size'],color = "skyblue")
plt.xlabel("Size",fontsize=16)
plt.title("Distribution of Size",fontsize=16)
plt.ylabel("Number of apps",fontsize=16)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is basically used to represent data provided in a form of some groups.It is accurate method for the graphical representation of numerical data distribution

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the app's size between 1 to 20Mb mins most of the apps are small in size

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From the histogram, we can say that most of the apps are small in size between 1 Mb to 20 Mb. we can insight that if the app size is beyond this range so maybe it leads to fewer installations.

# %% [markdown]
# #### Chart - 10 Line Chart

# %%
# Chart - 10 visualization code
#dataset on rating, reviews,installs,size and price
df2=df1[["Rating","Reviews","Installs","Size","Price"]]
df2
# Out:
#        Rating  Reviews  Installs  Size  Price
# 0        4.10      159     10000  19.0    0.0
# 1        3.90      967    500000  14.0    0.0
# 2        4.70    87510   5000000   8.7    0.0
# 3        4.50   215644  50000000  25.0    0.0
# 4        4.30      967    100000   2.8    0.0
# ...       ...      ...       ...   ...    ...
# 10836    4.50       38      5000  53.0    0.0
# 10837    5.00        4       100   3.6    0.0
# 10838    4.19        3      1000   9.5    0.0
# 10839    4.50      114      1000  20.0    0.0
# 10840    4.50   398307  10000000  19.0    0.0
#
# [9659 rows x 5 columns]

# %%
#df2 information
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9659 entries, 0 to 10840
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rating    9659 non-null   float64
#  1   Reviews   9659 non-null   int64
#  2   Installs  9659 non-null   int64
#  3   Size      9659 non-null   float64
#  4   Price     9659 non-null   float64
# dtypes: float64(3), int64(2)
# memory usage: 452.8 KB

# %%
#apps based on rating,reviews,installs,size and price
rating_df = df2.groupby('Rating').sum().reset_index()
rating_df
# Out:
#     Rating    Reviews     Installs        Size    Price
# 0     1.00         28         5170    228.8000     4.48
# 1     1.20         44         1000     27.0000     0.00
# 2     1.40         98         7000     20.2000     0.00
# 3     1.50         61         1105     54.0000     0.00
# 4     1.60        691       152000     64.6000     0.00
# 5     1.70       2360        81700     80.3000     4.99
# 6     1.80       3418       519500     49.0870     1.49
# 7     1.90       1874       189000    174.2000     0.00
# 8     2.00       2997      5040150    211.4000     4.59
# 9     2.10       3073       182000    164.2000     0.00
# 10    2.20       1979      2130600    217.4000     0.00
# 11    2.30       2361       264100    344.6000     2.48
# 12    2.40      14829      1284100    275.8090     5.98
# 13    2.50      14807      2078100    399.8620     3.99
# 14    2.60       3761       442600    262.8360    16.98
# 15    2.70      25048      3359700    403.1700     7.98
# 16    2.80     124730      3489150    681.1720     6.97
# 17    2.90      57937      7191100    712.6850   412.95
# 18    3.00     161473     34233880   1372.3160    25.42
# 19    3.10     320836    106558500   1264.6280    12.96
# 20    3.20     226913     28574400    867.0760     4.98
# 21    3.30    1548893     94846800   1549.8820    27.45
# 22    3.40     951726    108413950   2219.2760    79.05
# 23    3.50    1552129    231078060   2965.5390   474.40
# 24    3.60    1651021    236516750   3538.0020   836.41
# 25    3.70    8142601   1584049960   4284.9640    34.89
# 26    3.80   10601457    605152500   6070.8970  1573.05
# 27    3.90   11446651   2932445300   7494.2700    72.13
# 28    4.00  100204794   3872940410  10848.6380   894.29
# 29    4.10  134511686   4813942600  13055.7820   936.85
# 30    4.19      26520      5862189  20264.7190  2111.63
# 31    4.20  123674307   9026527160  18034.9820   266.94
# 32    4.30  306206195  16056236710  21608.1060   978.01
# 33    4.40  395625842  13380719100  21732.8610   654.13
# 34    4.50  506989995  12698218960  20609.0000   301.17
# 35    4.60  326843729   6258231800  15709.7675   369.44
# 36    4.70  138299879   2607274010   8864.2040   225.42
# 37    4.80   20877708    381724990   4303.5630   145.66
# 38    4.90    1940739     32882600   1633.7340    18.94
# 39    5.00       2384        88823   3849.5520   102.03

# %%
#graph on size,rating,review etc
fig, axes = plt.subplots(1, 4, figsize=(15, 4))

axes[0].plot(rating_df['Rating'], rating_df['Reviews'], 'r')
axes[0].set_xlabel('Rating')
axes[0].set_ylabel('Reviews')
axes[0].set_title('Reviews Per Rating',fontsize=16)

axes[1].plot(rating_df['Rating'], rating_df['Size'], 'g')
axes[1].set_xlabel('Rating')
axes[1].set_ylabel('Size')
axes[1].set_title('Size Per Rating',fontsize=16)

axes[2].plot(rating_df['Rating'], rating_df['Installs'], 'y')
axes[2].set_xlabel('Rating')
axes[2].set_ylabel('Installs (e+10)')
axes[2].set_title('Installs Per Rating',fontsize=16)

axes[3].plot(rating_df['Rating'], rating_df['Price'], 'm')
axes[3].set_xlabel('Rating')
axes[3].set_ylabel('Price')
axes[3].set_title('Price Per Rating',fontsize=16)

plt.tight_layout(pad=2)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart displays the evolution of one or several numeric variables

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above plottings, we can imply that most of the apps with higher rating range of 4.0 - 4.7 are having high amount of reviews, size, and installs. In terms of price, it doesn't reflect a direct relationship with rating, as we could see a fluctuation in term of pricing even at the range of high rating.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From the above plottings, we can imply that most of the apps with a higher rating range of 4.0 - 4.7 are having a high amount of reviews, sizes, and installs. In terms of price, it doesn't reflect a direct relationship with rating, as we could see a fluctuation in terms of pricing even at the range of high rating. From these conclusions, we draw an insight that the popularity of apps or ratings of apps is strongly correlated with the number of reviews, the size of the app, and the number of installs.

# %% [markdown]
# #### Chart - 11  Correlation Heatmap

# %%
# Chart - 11 visualization code
fig, axes = plt.subplots(figsize=(8, 8))
plt.title("co-relations of variables using a heatmap", fontsize=16)
sns.heatmap(rating_df.corr(), ax=axes, annot=True, linewidths=0.1, fmt='.2f', square=True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because it makes patterns easily readable and highlights the differences and variations in the same data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From our heatmap, we can visualize the correlation of the variables. some visualizations from the map are -
#
# 1-The correlation between reviews and price is very low
#
# 2-The correlation between reviews and installation is very high
#
# 3- The moderate correlation variables are price vs rating, rating vs installation
#
# 4-The very low correlation between price, reviews, and installs.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From the above heatmap, we can say that the correlation between Installation, size, and reviews of the apps gain a positive impact on business, and the relation between price, Installation, and Reviews has a negative or less positive impact on business.

# %% [markdown]
# #### Chart - 12 Pair Plot

# %%
# Chart - 12 visualization code
g=sns.pairplot(rating_df)
g.fig.suptitle("Distribution and relation of data ", y=1.00,fontsize=16)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because Pair plot is used to understand the best set of features to explain a relationship between two variables or to form the most separated clusters. It also helps to form some simple classification models by drawing some simple lines or make linear separation in our data-set.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Relation between reviews and price is very low
#
# Relation between reviews and installation is very high
#
# Moderate relation variables are price vs rating, rating vs installation
#
# very low relation between price, reviews, and installs.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Relation between Installation, size, and reviews of the apps gain a positive impact on business, and the relation between price, Installation, and Reviews has a negative impact on business.

# %% [markdown]
# #### Chart - 13 Scatterplot

# %%
# Chart - 13 visualization code
#scaterplot on apps rating based on price
plt.figure(figsize=(12, 6))
sns.scatterplot(data=price_df,x=price_df['Size'],y=price_df['Rating'],hue=price_df['Type'],s=50)
plt.xlabel("Size",fontsize=16)
plt.ylabel("Rating",fontsize=16)
plt.title("Apps rating ,size and type",fontsize=16)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scatter plots are used to plot data points on horizontal and vertical axis in the attempt to show how much one variable is affected by another.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this scatter plot, we can imply that majority of the free apps are small in size and having high rating. While for paid apps, we have quite equal distribution in term on size and rating.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From this scatter plot, we can imply that the majority of the apps are free and small in size with a high rating. While for paid apps, we have quite equal distribution in terms of size and rating it mins if the apps are small in size it may lead to high installations and reviews

# %% [markdown]
# #### Chart - 14 - Bar Plot

# %%
#installs unique values
df1["Installs"].unique()
# Out:
# array([     10000,     500000,    5000000,   50000000,     100000,
#             50000,    1000000,   10000000,       5000,  100000000,
#        1000000000,       1000,  500000000,         50,        100,
#               500,         10,          1,          5,          0])

# %%
#set in decending order
top_installers=df1.sort_values(by='Installs', ascending=False)
top_apps_by_instolation=top_installers.head(20)

# %%
#top 20 apps based on installs
top_apps_by_instolation[["App","Category","Installs"]]
# Out:
#                                            App             Category  \
# 336                         WhatsApp Messenger        COMMUNICATION
# 152                          Google Play Books  BOOKS_AND_REFERENCE
# 1654                            Subway Surfers                 GAME
# 3117                 Maps - Navigate & Explore     TRAVEL_AND_LOCAL
# 340                                      Gmail        COMMUNICATION
# 2545                                 Instagram               SOCIAL
# 2544                                  Facebook               SOCIAL
# 338               Google Chrome: Fast & Secure        COMMUNICATION
# 2554                                   Google+               SOCIAL
# 3665                                   YouTube        VIDEO_PLAYERS
# 3127                        Google Street View     TRAVEL_AND_LOCAL
# 3234                                    Google                TOOLS
# 3454                              Google Drive         PRODUCTIVITY
# 865                          Google Play Games        ENTERTAINMENT
# 2808                             Google Photos          PHOTOGRAPHY
# 335   Messenger – Text and Video Chat for Free        COMMUNICATION
# 3736                               Google News   NEWS_AND_MAGAZINES
# 3687                   Google Play Movies & TV        VIDEO_PLAYERS
# 391              Skype - free IM & video calls        COMMUNICATION
# 341                                   Hangouts        COMMUNICATION
#
#         Installs
# 336   1000000000
# 152   1000000000
# 1654  1000000000
# 3117  1000000000
# 340   1000000000
# 2545  1000000000
# 2544  1000000000
# 338   1000000000
# 2554  1000000000
# 3665  1000000000
# 3127  1000000000
# 3234  1000000000
# 3454  1000000000
# 865   1000000000
# 2808  1000000000
# 335   1000000000
# 3736  1000000000
# 3687  1000000000
# 391   1000000000
# 341   1000000000

# %% [markdown]
# The top 20 apps were installed above 1 billion.

# %%
#total apps by category based on top installs
top_category_apps=top_apps_by_instolation.groupby("Category")["App"].count().reset_index(name="total app")
top_category_apps=top_category_apps.sort_values(by="total app",ascending=False)
top_category_apps
# Out:
#                Category  total app
# 1         COMMUNICATION          6
# 7                SOCIAL          3
# 9      TRAVEL_AND_LOCAL          2
# 10        VIDEO_PLAYERS          2
# 0   BOOKS_AND_REFERENCE          1
# 2         ENTERTAINMENT          1
# 3                  GAME          1
# 4    NEWS_AND_MAGAZINES          1
# 5           PHOTOGRAPHY          1
# 6          PRODUCTIVITY          1
# 8                 TOOLS          1

# %% [markdown]
# from all the category communication 6 apps installed is above 1 billion

# %%
#bar graph on category in top installs
plt.figure(figsize=(10, 6))
sns.barplot(x='Category', y='total app', data=top_category_apps)
plt.xticks(rotation=90)
plt.xlabel("Category",fontsize=16)
plt.ylabel('number of apps',fontsize=16)
plt.title('Number of apps From Each Category were 1bilion or above installations',fontsize=16)
plt.show()

# %% [markdown]
# **From the communication , appps were installation above one billion.**
#
# 1- Whattsup Messenger
#
# 2- Gmail
#
# 3-Google chrome
#
# 4- Messenger
#
# 5-Skype
#
# 6-Hangout

# %%
top_installers[["App"]].tail()
# Out:
#                             App
# 9917                Eu Sou Rico
# 6692              cronometra-br
# 5486     AP Series Solution Pro
# 9719               EP Cook Book
# 9148  Command & Conquer: Rivals

# %% [markdown]
# **Least performed and installed apps are**
#
# 1-Eu sou Rico
#
# 2-cronometra
#
# 3ap series solution pro
#
# 4ep cook book
#
# 5command and conquer:Rivels

# %%
#top five apps based on price
most_expensive_app=df1
most_expensive_app.sort_values(by="Price",ascending=False)
# Out:
#                                                  App      Category  Rating  \
# 4367                        I'm Rich - Trump Edition     LIFESTYLE    3.60
# 9934               I'm Rich/Eu sou Rico/أنا غني/我很有錢     LIFESTYLE    4.19
# 5359                              I am rich(premium)       FINANCE    3.50
# 5358                                      I am Rich!       FINANCE    3.80
# 5373                              I AM RICH PRO PLUS       FINANCE    4.00
# ...                                              ...           ...     ...
# 4078                  Moto LED for Moto X & E [Root]     LIFESTYLE    3.40
# 4079                     Mobile Security & Antivirus  PRODUCTIVITY    4.70
# 4080                    Lookout Security & Antivirus         TOOLS    4.40
# 4081                      World History Quick e-Book        FAMILY    4.40
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology     LIFESTYLE    4.50
#
#        Reviews   Installs   Price  Type               Genres Content Rating  \
# 4367       275      10000  400.00  Paid            Lifestyle       Everyone
# 9934         0          0  399.99  Paid            Lifestyle       Everyone
# 5359       472       5000  399.99  Paid              Finance       Everyone
# 5358        93       1000  399.99  Paid              Finance       Everyone
# 5373        36       1000  399.99  Paid              Finance       Everyone
# ...        ...        ...     ...   ...                  ...            ...
# 4078      4082     500000    0.00  Free            Lifestyle       Everyone
# 4079    564759   10000000    0.00  Free         Productivity       Everyone
# 4080    951413  100000000    0.00  Free                Tools       Everyone
# 4081      1657     100000    0.00  Free  Education;Education       Everyone
# 10840   398307   10000000    0.00  Free            Lifestyle       Everyone
#
#          Size
# 4367    7.300
# 9934   40.000
# 5359    0.965
# 5358   22.000
# 5373   41.000
# ...       ...
# 4078    0.318
# 4079   20.000
# 4080   13.000
# 4081    4.900
# 10840  19.000
#
# [9659 rows x 10 columns]

# %% [markdown]
# **Top most expensive apps are**
#
# 1- im rich - trump edition
#
# 2- I'm Rich/Eu sou Rico/أنا غني/我很有錢
#
# 3-I am rich(premium)
#
# 4-I am Rich!
#
# 5-I AM RICH PRO PLUS

# %%
#top five apps based on reviews
apps_Reviews=df1.sort_values(by='Reviews', ascending=False)
apps_Reviews[["App","Reviews"]].head()
# Out:
#                                            App   Reviews
# 2544                                  Facebook  78158306
# 336                         WhatsApp Messenger  69119316
# 2545                                 Instagram  66577313
# 335   Messenger – Text and Video Chat for Free  56642847
# 1670                            Clash of Clans  44891723

# %% [markdown]
# **Top revieved apps.**
# 1- facebook
#
# 2- whattsup messenger
#
# 3- instagram
#
# 4- messenger
#
# 5- clash of clans

# %%
#top app in game category
df = df1[df1['Category'] == 'GAME']
df = df.sort_values(by=['Installs'], ascending=False)
df[["App","Category","Installs"]].head()
# Out:
#                    App Category    Installs
# 1654    Subway Surfers     GAME  1000000000
# 1655  Candy Crush Saga     GAME   500000000
# 1661      Temple Run 2     GAME   500000000
# 1662               Pou     GAME   500000000
# 1722    My Talking Tom     GAME   500000000

# %% [markdown]
# **Yop apps from gallery category.**
#
# 1- subway surfer
#
# 2- candy crush sage
#
# 3- temple run
#
# 4- pou
#
# 5-my talkimng tom

# %%
#least preferd apps in family category
df = df1[df1['Category'] == 'FAMILY']
df = df.sort_values(by=['Rating'], ascending=True)
df[["App","Category","Installs","Rating"]].head()
# Out:
#                                   App Category  Installs  Rating
# 5978    Truck Driving Test Class 3 BC   FAMILY        50     1.0
# 10324  FE Mechanical Engineering Prep   FAMILY      1000     1.0
# 4127                Speech Therapy: F   FAMILY        10     1.0
# 4905          AC REMOTE UNIVERSAL-PRO   FAMILY    100000     1.6
# 9176                        EB Mobile   FAMILY     10000     1.7

# %% [markdown]
# **Least rating apps from the family category are **
#
# 1- 1-Truck Driving Test Class 3 BC
#
# 2-FE Mechanical Engineering Prep
#
# 3-Speech Therapy: F
#
# 4-AC REMOTE UNIVERSAL-PRO
#
# 5-EB Mobile

# %%
#top genres on installs
Genres= df1.groupby("Genres")["Installs"].sum().reset_index()
Genres1= Genres.sort_values(by=['Installs'], ascending=False)
Genres1.head()
# Out:
#             Genres     Installs
# 35   Communication  11038276251
# 107          Tools   7991771915
# 81    Productivity   5793091369
# 100         Social   5487867902
# 80     Photography   4649147655

# %% [markdown]
# Top genres that most people like are-
#
# 1-Communication
#
# 2-Tools
#
# 3-Productivity
#
# 4-Social
#
# 5-Photography

# %%
#least genres
Genres1.tail()
# Out:
#                            Genres  Installs
# 21    Books & Reference;Education     11000
# 93         Role Playing;Education       100
# 112              Trivia;Education       100
# 18             Board;Pretend Play       100
# 20   Books & Reference;Creativity       100

# %% [markdown]
# **Least preferd genres apps are-**
#
# 1-Books & Reference;Education
#
# 2-Role Playing;Education
#
# 3-Trivia;Education
#
# 4-Board;Pretend Play
#
# 5-Books & Reference;Creativity

# %% [markdown]
# ## **Dataset-2**

# %%
#dataset two top rows
ps_df2.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
#last five rows
ps_df2.tail()
# Out:
#                                App Translated_Review Sentiment  \
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN

# %%
#shape of data
ps_df2.shape
# Out:
# (64295, 5)

# %%
#shape of data
ps_df2.shape
# Out:
# (64295, 5)

# %%
#basic statistics
ps_df2.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %% [markdown]
# **What is a Sentiment polarity?**
#
# Sentiment polarity for an element defines the orientation of the expressed sentiment, i.e., it determines if the text expresses the positive, negative or neutral sentiment of the user about the entity in consideration

# %% [markdown]
# **What is a sentiment Subjectivity ?**
#
# Subjectivity quantifies the amount of personal opinion and factual information contained in the text. The higher subjectivity means that the text contains personal opinion rather than factual information.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# As per the buisssness objective , there are some useful insights.
#
# In the android market some free apps have more installation.
#
# GAMES, SOCIAL, COMUNICATION, and TOOL this categories are having the haighest amount of installations.
#
# Generally the median size of all the apps is 12 MB.
#
# App should be variable with the android versions.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The Google Play Store Apps report offers several insightful observations about the trends and characteristics of apps on the platform:
#
# * Categories such as GAME, COMMUNICATION, and TOOL are dominating the trending apps in terms of user installs, even though they have fewer apps compared to the FAMILY category. This trend is likely due to the entertainment or utility value these categories provide. It also suggests that developers in these categories prioritize app quality over quantity.
#
# * Apps with high ratings (above 4.0) tend to have a substantial number of reviews and user installs. This implies that user feedback and ratings are important factors influencing an app's popularity and success.
#
# * While there are occasional spikes in app size and price, they do not necessarily correlate with high ratings. Most high-rated apps are not exceptionally large or expensive. These spikes may be attributed to outliers or a minority of apps.
#
# * The categories SOCIAL, COMMUNICATION, and GAME stand out as having the highest number of reviews, featuring apps like Facebook, WhatsApp Messenger, Instagram, and Clash of Clans. These categories are evidently popular among users who engage with and review apps frequently.
#
# * Although GAME, SOCIAL, COMMUNICATION, and TOOL categories have the highest installs, ratings, and reviews, they are not among the top 5 categories with the most expensive apps. Categories like FINANCE and LIFESTYLE dominate the list of pricier apps.
#
# * A significant percentage (~92%) of apps on the Play Store are free, indicating that the freemium model or ad-supported apps are prevalent.
#
# * Approximately 82% of apps do not have age restrictions, suggesting that many apps are designed to be accessible to a broad audience.
#
# * The FAMILY category is noted as one of the most competitive categories, indicating a high number of apps vying for user attention.
#
# * There are 20 free apps that have been installed over a billion times, highlighting the potential for widespread adoption.
#
# * Minecraft, a paid app, stands out with over 10 million installs and significant revenue from installation fees. This showcases the potential for revenue generation through paid apps in the gaming category.
#
# * The FINANCE category is highlighted as having the highest average installation fees for paid apps.
#
# * Facebook is identified as the most popular app in the Play Store based on the number of reviews.
#
# * The median size of all apps in the Play Store is 12 MB, indicating that apps generally have a reasonable file size.
#
# In conclusion, the report underscores the current trends in the Android market, with categories related to entertainment, communication, and utility apps standing out. It also highlights the importance of user ratings and reviews in app success, the dominance of free apps, and the diversity of app categories in terms of pricing and competitiveness. These insights can inform strategic decisions for developers and businesses operating in the Android app ecosystem.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
